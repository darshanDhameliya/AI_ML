# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_staic_lead = pd.read_csv('/home/darshan/Documents/static_lead_level_with_specific_columns_dataset_dec_11.csv', low_memory=False)

df_staic_lead.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264118 entries, 0 to 264117
# Data columns (total 45 columns):
#  #   Column                                               Non-Null Count   Dtype
# ---  ------                                               --------------   -----
#  0   Unnamed: 0                                           264118 non-null  int64
#  1   account                                              264085 non-null  object
#  2   domain                                               264118 non-null  object
#  3   first_name                                           264114 non-null  object
#  4   last_name                                            264118 non-null  object
#  5   title                                                153897 non-null  object
#  6   work_email                                           264118 non-null  object
#  7   member_type                                          264118 non-null  object
# ...

# %%
df_staic_lead[df_staic_lead['title'].notnull()].sample(20)
# Out:
#         Unnamed: 0                                        account  \
# 157059      157059                             UnitedHealth Group
# 168289      168289                                  Kabbage, Inc.
# 55467        55467                                  Radius Online
# 130406      130406                            founderscnc:Houston
# 34246        34246  Northwoods Life Church:Northwoods Life Church
# 138622      138622               Ortho-Clinical Diagnostics, Inc.
# 148815      148815                        Panos & Associates, LLC
# 46377        46377                                      Cognizant
# 8227          8227                                      Chess ICT
# 181219      181219             American International Group, Inc.
# 137855      137855                                      Honeywell
# 204254      204254                            Lindsay Corporation
# 223461      223461           University of Maryland, College Park
# ...
